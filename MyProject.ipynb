# %%
print('hello')
# Out:
# hello

# %%
"hello again"
# Out:
# 'hello again'

# %%
print("hello again")
# Out:
# hello again

# %%
import pandas as pd

# %%
pd.read_csv('https://raw.githubusercontent.com/darrenk6/UCDPA-Darren-keane/main/stud.csv')
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# 1           IT        F   Father           20                20
# 2           IT        F   Father           10                 7
# 3           IT        F   Father           30                25
# 4           IT        F   Father           40                50
# ..         ...      ...      ...          ...               ...
# 475  Chemistry        S   Father            5                 4
# 476    Geology        F   Father           50                77
# 477    Geology        S   Father           55                74
# 478    History        F   Father           30                17
# 479    History        S   Father           35                14
#
#      AnnouncementsView  Discussion ParentAnsweringSurvey  \
# 0                    2          20                   Yes
# 1                    3          25                   Yes
# 2                    0          30                    No
# 3                    5          35                    No
# 4                   12          50                    No
# ..                 ...         ...                   ...
# 475                  5           8                    No
# 476                 14          28                    No
# 477                 25          29                    No
# 478                 14          57                    No
# 479                 23          62                    No
#
#     ParentschoolSatisfaction StudentAbsenceDays Class
# 0                       Good            Under-7     M
# 1                       Good            Under-7     M
# 2                        Bad            Above-7     L
# 3                        Bad            Above-7     L
# 4                        Bad            Above-7     M
# ..                       ...                ...   ...
# 475                      Bad            Above-7     L
# 476                      Bad            Under-7     M
# 477                      Bad            Under-7     M
# 478                      Bad            Above-7     L
# 479                      Bad            Above-7     L
#
# [480 rows x 17 columns]

# %%
pd.read_csv('https://raw.githubusercontent.com/darrenk6/UCDPA-Darren-keane/main/heart.csv',)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f9bda58aaff2> in <module>
# ----> 1 pd.read_csv('https://raw.githubusercontent.com/darrenk6/UCDPA-Darren-keane/main/heart.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
pd.read_csv('https://raw.githubusercontent.com/darrenk6/UCDPA-Darren-keane/main/heart.csv',)
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# 1      0      2       1
# 2      0      2       1
# 3      0      2       1
# 4      0      2       1
# ..   ...    ...     ...
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0
#
# [303 rows x 14 columns]

# %%
heart = pd.read_csv("https://raw.githubusercontent.com/darrenk6/UCDPA-Darren-keane/main/heart.csv",index_col = 0)

# %%
heart ['age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Downloads\New folder\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-f11f8d151c79> in <module>
# ----> 1 heart ['age']
#
# ~\Downloads\New folder\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\Downloads\New folder\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'age'

# %%
heart
# Out:
#      sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  \
# age
# 63     1   3     145   233    1        0       150     0      2.3    0    0
# 37     1   2     130   250    0        1       187     0      3.5    0    0
# 41     0   1     130   204    0        0       172     0      1.4    2    0
# 56     1   1     120   236    0        1       178     0      0.8    2    0
# 57     0   0     120   354    0        1       163     1      0.6    2    0
# ..   ...  ..     ...   ...  ...      ...       ...   ...      ...  ...  ...
# 57     0   0     140   241    0        1       123     1      0.2    1    0
# 45     1   3     110   264    0        1       132     0      1.2    1    0
# 68     1   0     144   193    1        1       141     0      3.4    1    2
# 57     1   0     130   131    0        1       115     1      1.2    1    1
# 57     0   1     130   236    0        0       174     0      0.0    1    1
#
#      thall  output
# age
# 63       1       1
# 37       2       1
# 41       2       1
# 56       2       1
# 57       2       1
# ..     ...     ...
# 57       3       0
# 45       3       0
# 68       3       0
# 57       3       0
# 57       2       0
#
# [303 rows x 13 columns]

# %%
heart ['chol']
# Out:
# age
# 63    233
# 37    250
# 41    204
# 56    236
# 57    354
#      ...
# 57    241
# 45    264
# 68    193
# 57    131
# 57    236
# Name: chol, Length: 303, dtype: int64

# %%
heart [["sex","chol"]]
# Out:
#      sex  chol
# age
# 63     1   233
# 37     1   250
# 41     0   204
# 56     1   236
# 57     0   354
# ..   ...   ...
# 57     0   241
# 45     1   264
# 68     1   193
# 57     1   131
# 57     0   236
#
# [303 rows x 2 columns]

# %%
heart
# Out:
#      sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  \
# age
# 63     1   3     145   233    1        0       150     0      2.3    0    0
# 37     1   2     130   250    0        1       187     0      3.5    0    0
# 41     0   1     130   204    0        0       172     0      1.4    2    0
# 56     1   1     120   236    0        1       178     0      0.8    2    0
# 57     0   0     120   354    0        1       163     1      0.6    2    0
# ..   ...  ..     ...   ...  ...      ...       ...   ...      ...  ...  ...
# 57     0   0     140   241    0        1       123     1      0.2    1    0
# 45     1   3     110   264    0        1       132     0      1.2    1    0
# 68     1   0     144   193    1        1       141     0      3.4    1    2
# 57     1   0     130   131    0        1       115     1      1.2    1    1
# 57     0   1     130   236    0        0       174     0      0.0    1    1
#
#      thall  output
# age
# 63       1       1
# 37       2       1
# 41       2       1
# 56       2       1
# 57       2       1
# ..     ...     ...
# 57       3       0
# 45       3       0
# 68       3       0
# 57       3       0
# 57       2       0
#
# [303 rows x 13 columns]

# %%
heart[1:10]
# Out:
#      sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  \
# age
# 37     1   2     130   250    0        1       187     0      3.5    0    0
# 41     0   1     130   204    0        0       172     0      1.4    2    0
# 56     1   1     120   236    0        1       178     0      0.8    2    0
# 57     0   0     120   354    0        1       163     1      0.6    2    0
# 57     1   0     140   192    0        1       148     0      0.4    1    0
# 56     0   1     140   294    0        0       153     0      1.3    1    0
# 44     1   1     120   263    0        1       173     0      0.0    2    0
# 52     1   2     172   199    1        1       162     0      0.5    2    0
# 57     1   2     150   168    0        1       174     0      1.6    2    0
#
#      thall  output
# age
# 37       2       1
# 41       2       1
# 56       2       1
# 57       2       1
# 57       1       1
# 56       2       1
# 44       3       1
# 52       3       1
# 57       2       1

# %%
heart
# Out:
#      sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  \
# age
# 63     1   3     145   233    1        0       150     0      2.3    0    0
# 37     1   2     130   250    0        1       187     0      3.5    0    0
# 41     0   1     130   204    0        0       172     0      1.4    2    0
# 56     1   1     120   236    0        1       178     0      0.8    2    0
# 57     0   0     120   354    0        1       163     1      0.6    2    0
# ..   ...  ..     ...   ...  ...      ...       ...   ...      ...  ...  ...
# 57     0   0     140   241    0        1       123     1      0.2    1    0
# 45     1   3     110   264    0        1       132     0      1.2    1    0
# 68     1   0     144   193    1        1       141     0      3.4    1    2
# 57     1   0     130   131    0        1       115     1      1.2    1    1
# 57     0   1     130   236    0        0       174     0      0.0    1    1
#
#      thall  output
# age
# 63       1       1
# 37       2       1
# 41       2       1
# 56       2       1
# 57       2       1
# ..     ...     ...
# 57       3       0
# 45       3       0
# 68       3       0
# 57       3       0
# 57       2       0
#
# [303 rows x 13 columns]

# %%
heart.iloc[[1,2,3],[0,1]]
# Out:
#      sex  cp
# age
# 37     1   2
# 41     0   1
# 56     1   1

# %%
heart
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-46ec13b2ae4e> in <module>
# ----> 1 heart
#
# NameError: name 'heart' is not defined

# %%
import pandas as pd

# %%
pd.read_csv('https://raw.githubusercontent.com/darrenk6/UCDPA-Darren-keane/main/heart.csv')
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# 1      0      2       1
# 2      0      2       1
# 3      0      2       1
# 4      0      2       1
# ..   ...    ...     ...
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0
#
# [303 rows x 14 columns]

# %%
import numpy as np

# %%
heart_data=pd.read_csv('https://raw.githubusercontent.com/darrenk6/UCDPA-Darren-keane/main/heart.csv')

# %%
print(heart_data.head())
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
print(heart_data.shape)
# Out:
# (303, 14)

# %%
droprows=heart_data.dropna()

# %%
print(heart_data.shape,droprows.shape)
# Out:
# (303, 14) (303, 14)

# %%
dropcolumns = heart_data.dropna(axis=1)

# %%
print(heart_data.shape,dropcolumns.shape)
# Out:
# (303, 14) (303, 14)

# %%
cleaned_data = heart_data.fillna(method='bfill', axis=0).fillna(0)

# %%
drop_duplicates= heart_data.drop_duplicates()

# %%
print(heart_data.shape,drop_duplicates.shape)
# Out:
# (303, 14) (302, 14)

# %%
heart = pd.read_csv('https://raw.githubusercontent.com/darrenk6/UCDPA-Darren-keane/main/heart.csv',)

# %%
heart
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# 1      0      2       1
# 2      0      2       1
# 3      0      2       1
# 4      0      2       1
# ..   ...    ...     ...
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0
#
# [303 rows x 14 columns]

# %%
heart
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# 1      0      2       1
# 2      0      2       1
# 3      0      2       1
# 4      0      2       1
# ..   ...    ...     ...
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0
#
# [303 rows x 14 columns]

# %%
import numpy as np

# %%
np.array(heart)
# Out:
# array([[63.,  1.,  3., ...,  0.,  1.,  1.],
#        [37.,  1.,  2., ...,  0.,  2.,  1.],
#        [41.,  0.,  1., ...,  0.,  2.,  1.],
#        ...,
#        [68.,  1.,  0., ...,  2.,  3.,  0.],
#        [57.,  1.,  0., ...,  1.,  3.,  0.],
#        [57.,  0.,  1., ...,  1.,  2.,  0.]])

# %%
heart_arr = np.array(heart)

# %%
heart_arr/2
# Out:
# array([[31.5,  0.5,  1.5, ...,  0. ,  0.5,  0.5],
#        [18.5,  0.5,  1. , ...,  0. ,  1. ,  0.5],
#        [20.5,  0. ,  0.5, ...,  0. ,  1. ,  0.5],
#        ...,
#        [34. ,  0.5,  0. , ...,  1. ,  1.5,  0. ],
#        [28.5,  0.5,  0. , ...,  0.5,  1.5,  0. ],
#        [28.5,  0. ,  0.5, ...,  0.5,  1. ,  0. ]])

# %%
heart_arr >2
# Out:
# array([[ True, False,  True, ..., False, False, False],
#        [ True, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False, False],
#        ...,
#        [ True, False, False, ..., False,  True, False],
#        [ True, False, False, ..., False,  True, False],
#        [ True, False, False, ..., False, False, False]])

# %%
heart_arr [heart_arr >2]
# Out:
# array([ 63.,   3., 145., ..., 130., 236., 174.])

# %%
np.mean(heart["age"])
# Out:
# 54.366336633663366

# %%
heart
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# 1      0      2       1
# 2      0      2       1
# 3      0      2       1
# 4      0      2       1
# ..   ...    ...     ...
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0
#
# [303 rows x 14 columns]

# %%
heart.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
heart.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trtbps        int64
# chol          int64
# fbs           int64
# restecg       int64
# thalachh      int64
# exng          int64
# oldpeak     float64
# slp           int64
# caa           int64
# thall         int64
# output        int64
# dtype: object

# %%
columns = ['age','sex','chol']
heart[columns]
# Out:
#      age  sex  chol
# 0     63    1   233
# 1     37    1   250
# 2     41    0   204
# 3     56    1   236
# 4     57    0   354
# ..   ...  ...   ...
# 298   57    0   241
# 299   45    1   264
# 300   68    1   193
# 301   57    1   131
# 302   57    0   236
#
# [303 rows x 3 columns]

# %%
heart[0:8]
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
# 5   57    1   0     140   192    0        1       148     0      0.4    1
# 6   56    0   1     140   294    0        0       153     0      1.3    1
# 7   44    1   1     120   263    0        1       173     0      0.0    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1
# 5    0      1       1
# 6    0      2       1
# 7    0      3       1

# %%
heart.drop_duplicates()
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# 1      0      2       1
# 2      0      2       1
# 3      0      2       1
# 4      0      2       1
# ..   ...    ...     ...
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0
#
# [302 rows x 14 columns]

# %%
heart_grouped=heart.groupby('[age]).mean()
# Out:
#   File "<ipython-input-56-df9b04fe15f0>", line 1
#     heart_grouped=heart.groupby('[age]).mean()
#                                               ^
# SyntaxError: EOL while scanning string literal

# %%
heart.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
heart
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# 1      0      2       1
# 2      0      2       1
# 3      0      2       1
# 4      0      2       1
# ..   ...    ...     ...
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0
#
# [303 rows x 14 columns]

# %%
import seaborn as sns

# %%
sns.load_dataset()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-2e24dd166ca8> in <module>
# ----> 1 sns.load_dataset()
#
# TypeError: load_dataset() missing 1 required positional argument: 'name'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-7f12449ae73e> in <module>
# ----> 1 heart.grouby('age')
#
# ~\Downloads\New folder\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'grouby'

# %%
pd.read_csv('https://raw.githubusercontent.com/darrenk6/UCDPA-Darren-keane/main/stud.csv')
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# 1           IT        F   Father           20                20
# 2           IT        F   Father           10                 7
# 3           IT        F   Father           30                25
# 4           IT        F   Father           40                50
# ..         ...      ...      ...          ...               ...
# 475  Chemistry        S   Father            5                 4
# 476    Geology        F   Father           50                77
# 477    Geology        S   Father           55                74
# 478    History        F   Father           30                17
# 479    History        S   Father           35                14
#
#      AnnouncementsView  Discussion ParentAnsweringSurvey  \
# 0                    2          20                   Yes
# 1                    3          25                   Yes
# 2                    0          30                    No
# 3                    5          35                    No
# 4                   12          50                    No
# ..                 ...         ...                   ...
# 475                  5           8                    No
# 476                 14          28                    No
# 477                 25          29                    No
# 478                 14          57                    No
# 479                 23          62                    No
#
#     ParentschoolSatisfaction StudentAbsenceDays Class
# 0                       Good            Under-7     M
# 1                       Good            Under-7     M
# 2                        Bad            Above-7     L
# 3                        Bad            Above-7     L
# 4                        Bad            Above-7     M
# ..                       ...                ...   ...
# 475                      Bad            Above-7     L
# 476                      Bad            Under-7     M
# 477                      Bad            Under-7     M
# 478                      Bad            Above-7     L
# 479                      Bad            Above-7     L
#
# [480 rows x 17 columns]

# %%
student = pd.read_csv('https://raw.githubusercontent.com/darrenk6/UCDPA-Darren-keane/main/stud.csv')

# %%
student.groupby(['gender']).mean()
# Out:
#         raisedhands  VisITedResources  AnnouncementsView  Discussion
# gender
# F         52.862857         64.000000          39.748571   47.828571
# M         43.281967         49.518033          36.868852   40.675410

# %%
heart['chol'].plot()
# Out:
# <AxesSubplot:>

# %%
heart
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# 1      0      2       1
# 2      0      2       1
# 3      0      2       1
# 4      0      2       1
# ..   ...    ...     ...
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0
#
# [303 rows x 14 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
heart.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
heart.plot(kind ='scatter',x='age',y='chol',s=10)
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
plt.scatter(heart['age'],heart['chol'],s=8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e8723843324b> in <module>
# ----> 1 plt.scatter(heart['age'],heart['chol'],s=8)
#
# NameError: name 'plt' is not defined

# %%
sns.scatterplot(data=heart,x='age',y = 'chol',hue='sex',size = 'age')
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
plt.plot(heart['age'],heart['sex'])

# %%
heart.plot.bar(age,sex)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-1802ac8cec26> in <module>
# ----> 1 heart.plot.bar(age,sex)
#
# NameError: name 'age' is not defined

# %%
plt.bar(oldpeak,sex)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-100-5f42fe167655> in <module>
# ----> 1 plt.bar(oldpeak,sex)
#
# NameError: name 'oldpeak' is not defined

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.plot.bar(x='smoker',y ='tip')
# Out:
# <AxesSubplot:xlabel='smoker'>

# %%
heart.groupby('chol').mean()['age'].plot.bar()
# Out:
# <AxesSubplot:xlabel='chol'>

# %%
sns.barplot(data=heart,x='chol',y ='age',hue='sex')
# Out:
# <AxesSubplot:xlabel='chol', ylabel='age'>

# %%
print('hello wade')
# Out:
# hello wade
